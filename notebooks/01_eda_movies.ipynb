# %% [markdown]
# # 01 — EDA Movies
#
# Owned by **Data Engineer**.
#
# Goals: schema check, duplicates, genre distribution, year extraction.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path("..").resolve()
movies = pd.read_csv(ROOT / "data" / "raw" / "movies.csv")
movies.head()

# %%
movies.shape, movies.dtypes, movies.isna().sum()
